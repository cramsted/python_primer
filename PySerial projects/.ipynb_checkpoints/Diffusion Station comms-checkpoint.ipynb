# %%
import serial
import time
from time import sleep

ser = serial.Serial('/dev/ttyUSB5', 9600)

sw0 = 0x1
sw1 = 0x2
sw2 = 0x4
sw3 = 0x8
sw4 = 0x10

while True: 
    if ser.inWaiting(): 
        temp = int(ser.readline(), 16)
        pot = int(temp >> 5)
        switches = temp & 0x1F
#         print("recieved")
#         print("Pot ", pot)
#         print("sw ", hex(switches))

        leds = 0x0
        if((switches & sw0) and (pot < 250)): 
            leds = 0x30
        elif((switches & sw1) and (pot < 500)):
            leds = 0x0C
        elif((switches & sw2) and (pot < 750)): 
            leds = 0xC0
        else:
            leds = 0x03
         
#         import pdb; pdb.set_trace()
        ser.write(array.array('B', [leds]).tostring())
        print("Leds ", leds)
#         print("sent")
#         time.sleep(1)
#         break

# %%
import serial
import struct
import array
from time import sleep

ser = serial.Serial('/dev/ttyUSB4', 9600)

while True: 
    leds = array.array('B', [0x03]).tostring()
    print(leds)
    ser.write(leds)
    sleep(2)
    leds = array.array('B', [0x0C]).tostring()
    print(leds)
    ser.write(leds)
    sleep(2)
    leds = array.array('B', [0x30]).tostring()
    print(leds)
    ser.write(leds)
    sleep(2)
    leds = array.array('B', [0xC0]).tostring()
    print(leds)
    ser.write(leds)
    sleep(2)
# Out:
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# b'\x03'
# b'\x0c'
# b'0'
# b'\xc0'
# ...
